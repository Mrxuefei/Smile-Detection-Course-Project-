# %%
# %matplotlib inline
from feature_representation import *
from learning import *

# %%
original_img_size = 48
x, y = load_smile_data_from_pickle("x.p", "y.p")
# Out:
# loading data...
# --- Load data in 15.1234269142 seconds ---
# data size is :  5330
# Positive labels:  2611
# Negtive labels:  2719

# %%
filters = build_gabor_filters(original_img_size)
x2 = apply_gabor_filters(x, original_img_size, filters)
clf2 = svm.LinearSVC(C=1000)
ac, cm, fpr, tpr, roc_auc = train_and_print_result(x2, y, clf2, "gabor filters")
# Out:
# ---Begin to train classifier with gabor filters
# true positive:    418
# true negtive:     455
# false positive:   89
# false negtive:    104
# total:            1066
# Error Rate        18.1%
# Acuracy:          81.9%
# ---Finished train classifier in 840.8 seconds ---

# %%
plot_confusion_matrix(cm)

# %%
plot_ROC(fpr, tpr, roc_auc)

# %%
x3 = get_hog_features(x)
clf3 = svm.LinearSVC(C=1000)
ac, cm, fpr, tpr, roc_auc = train_and_print_result(x3, y, clf3, "HoG features")
# Out:
# ---Begin to train classifier with HoG features
# true positive:    482
# true negtive:     280
# false positive:   264
# false negtive:    40
# total:            1066
# Error Rate        28.5%
# Acuracy:          71.5%
# ---Finished train classifier in 1.7 seconds ---

# %%
plot_confusion_matrix(cm)

# %%
plot_ROC(fpr, tpr, roc_auc)

# %%
x4 = get_img_pca(x)
clf4 = svm.LinearSVC(C=1000)
ac, cm, fpr, tpr, roc_auc = train_and_print_result(x4, y, clf4, "PCA features")
# Out:
# ---Begin to train classifier with PCA features
# true positive:    291
# true negtive:     258
# false positive:   286
# false negtive:    231
# total:            1066
# Error Rate        48.5%
# Acuracy:          51.5%
# ---Finished train classifier in 12.6 seconds ---

# %%
plot_confusion_matrix(cm)

# %%
plot_ROC(fpr, tpr, roc_auc)

# %%
x5 = get_img_pca(x)
clf5 = svm.LinearSVC(C=1000)
ac, cm, fpr, tpr, roc_auc = train_and_print_result(x5, y, clf5, "area of interest")
# Out:
# ---Begin to train classifier with area of interest
# true positive:    210
# true negtive:     339
# false positive:   205
# false negtive:    312
# total:            1066
# Error Rate        48.5%
# Acuracy:          51.5%
# ---Finished train classifier in 12.7 seconds ---

# %%
plot_confusion_matrix(cm)

# %%
plot_ROC(fpr, tpr, roc_auc)

# %%
x6 = get_sift_features(x)
clf6 = svm.LinearSVC(C=1000)
ac, cm, fpr, tpr, roc_auc = train_and_print_result(x6, y, clf6, "SIFT features")
# Out:
# ---Begin to train classifier with SIFT features
# true positive:    303
# true negtive:     364
# false positive:   180
# false negtive:    219
# total:            1066
# Error Rate        37.4%
# Acuracy:          62.6%
# ---Finished train classifier in 12.3 seconds ---

# %%
plot_confusion_matrix(cm)

# %%
plot_ROC(fpr, tpr, roc_auc)

# %%
x1 = scale_image(x, 24)
x1 = get_pixels_diff(x1)
clf1 = AdaBoostClassifier(n_estimators=2000)
ac, cm, fpr, tpr, roc_auc = train_and_print_result(x1, y, clf1, "pixels differences")

# %%
plot_confusion_matrix(cm)

# %%
plot_ROC(fpr, tpr, roc_auc)
